# %% [markdown]
# # ***OOP***

# %%
class Atm:
    def __init__(self):
        self.__pin=""
        self.__balance=0

        self.__menu()
        
    def get_pin(self):
        return self.__pin

    def set_pin(self,new_pin):
         if type(new_pin)==str:
             self.__pin=new_pin
             print("Pin changed")
             
         else:
             print("Not allowed")
            
            

    
    def __menu(self):
        user_input=input(""" 
                Hello! How would you like to Proceed ?
                1.Enter 1 to create pin
                2.Enter 2 to deposit
                3.Enter 3 to withdraw
                4.Enter 4 to check Balance
                5.Enter 5 to Exit.
""")
        
        if user_input=="1":
            self.create_pin()
            
        elif user_input=="2":
            self.deposit()
            
        elif user_input=="3":
            self.withdraw()
            
        elif user_input=="4":
            self.check_balance()
            
        else:
            print("Bye")

    def create_pin(self):
        self.__pin=input("Enter Your Pin")
        print("Pin Generated ")

        
    def deposit (self):
        temp=input("Emter Your Pin")
        
        if temp==self.__pin:
            amount=int(input("Enter Amount"))
            self.__balance=self.__balance+amount
            print("Amount Deposited")
        else:
            print("Invalid Pin")
            
    def withdraw(self):
        temp=input("Enter your pin")
        
        if temp==self.__pin:
            amount=int(input("Enter your amoun"))
            
            if amount<self.__balance:
                self.__balance=self.__balance-amount
                print("Withdraw succesfull")
            
            else:
                print("Insufficient Funds")
        else :
            print("Invalid Pin")
            
    def check_balance(self):
        temp=input("Enter your pin")

        if temp==self.__pin:
            print(self.__balance)

        else:
            print("Invalid pin")

# %%
sbi=Atm()
# Out:
#
#                 Hello! How would you like to Proceed ?
#                 1.Enter 1 to create pin
#                 2.Enter 2 to deposit
#                 3.Enter 3 to withdraw
#                 4.Enter 4 to check Balance
#                 5.Enter 5 to Exit.
#  1
# Enter Your Pin 2234
# Pin Generated

# %%
sbi.deposit()
# Out:
# Emter Your Pin 2234
# Enter Amount 45089
# Amount Deposited

# %%
sbi.withdraw()
# Out:
# Enter your pin 2234
# Enter your amoun 6000
# Withdraw succesfull

# %%
sbi.check_balance()
# Out:
# Enter your pin 2234
# 39089

# %%
hdfc=Atm()
# Out:
#
#                 Hello! How would you like to Proceed ?
#                 1.Enter 1 to create pin
#                 2.Enter 2 to deposit
#                 3.Enter 3 to withdraw
#                 4.Enter 4 to check Balance
#                 5.Enter 5 to Exit.
#  1
# Enter Your Pin 1111
# Pin Generated

# %%
hdfc.deposit()
# Out:
# Emter Your Pin 1111
# Enter Amount 55000
# Amount Deposited

# %%
hdfc.check_balance()
# Out:
# Enter your pin 1111
# 55000

# %%
hdfc.withdraw()
# Out:
# Enter your pin 1111
# Enter your amoun 50000
# Withdraw succesfull

# %%
hdfc.check_balance()
# Out:
# Enter your pin 1111
# 5000

# %% [markdown]
# ### 🔹 Encapsulation in Python
#
# - Encapsulation means hiding data (variables) and controlling access to it using methods.

# %% [markdown]
# - Protect data from unwanted changes
# - Improve security
# - Control how data is accessed/modified

# %%
sbi=Atm()
# Out:
#
#                 Hello! How would you like to Proceed ?
#                 1.Enter 1 to create pin
#                 2.Enter 2 to deposit
#                 3.Enter 3 to withdraw
#                 4.Enter 4 to check Balance
#                 5.Enter 5 to Exit.
#  1
# Enter Your Pin 7890
# Pin Generated

# %%
sbi.get_pin()
# Out:
# '7890'

# %%
sbi.set_pin(5.6)
# Out:
# Not allowed

# %%
sbi.set_pin("9900")
# Out:
# Pin changed
