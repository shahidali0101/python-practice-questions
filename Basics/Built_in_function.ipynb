# %% [markdown]
# ## 1. Print

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## 2. Input

# %%
input("Enter anything Here")
# Out:
# Enter anything Here Hii
# 'Hii'

# %% [markdown]
# ## 3. Type

# %%
a=3.4
print(type(a))
b=5
print(type(b))
c="OHK"
print(type(c))
d=True
print(type(d))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## 4. abs

# %%
abs(-9)
# Out:
# 9

# %% [markdown]
# ## 5. pow

# %%
pow(2,3)
# Out:
# 8

# %% [markdown]
# ## 6. min/max

# %%
a=min([3,4,5,6,7,81,2,3,0])
b=min("Agra")
print(a)
print(b)
c=max([3,4,5,6,7,81,2,3,0])
d=max("Agra")
print(c,d,sep="\n")
# Out:
# 0
# A
# 81
# r

# %% [markdown]
# ## 7. round

# %%
r=22/7
print(round(r))
print(round(r,1))
# Out:
# 3
# 3.1

# %% [markdown]
# ## 8. divmod

# %%
divmod(5,2)
# Out:
# (2, 1)

# %% [markdown]
# ## 9. bin/oct/hex

# %%
print(bin(3))
print(oct(5))
print(hex(5))
# Out:
# 0b11
# 0o5
# 0x5

# %% [markdown]
# ## 10. id

# %%
id(a)
# Out:
# 140730500948872

# %% [markdown]
# ## 11. ord (American charactor encoding standard)

# %%
print(ord('a'))
print(ord('A'))
# Out:
# 97
# 65

# %% [markdown]
# ## 12. len

# %%
len([2,4,5,3,7])
# Out:
# 5

# %% [markdown]
# ## 13. sum

# %%
sum([2,3,4,5,6])
# Out:
# 20

# %% [markdown]
# ## 14. help  (to know about python function or module)

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help('modules')
