# %%
print("hello")
# Out:
# hello

# %%
# 1. Show the length of the text with space.

# %%
x="python is a programming language"
print(len(x))
# Out:
# 32

# %%
# 2. Show the length of the text with space.

# %%
x="python is a programming language"
y=x.replace(" ","")
print(len(y))
# Out:
# 28

# %%
x="python is a programming language"
y=len(x)-x.count(" ")
print(y)
# Out:
# 28

# %%
# 3. Write a Python program to convert a string to uppercase if its length > 5 else to lowercase 

s = input("Enter your string")
if len(s)>=5 :
    print(s.upper())
else:
    print(s.lower())
# Out:
# Enter your string workingday
# WORKINGDAY

# %%
# 4. WAP by user input ,if name startwith "p","r","a" or "m" 

u = input("Enter any string")
if u[0] in "pram":
    print("yes")
else:
    print("no")
# Out:
# Enter any string paark
# yes

# %%
# 5. WAP to check id name start and endswith "a" then show "yes" else "NO".

id = input("Enter your name :- ")

if id.endswith("a"):
    print("yes")
else:
    print("no")
# Out:
# Enter your name :-  banana
# yes

# %%
# 6.  replece i with this "*" '''
x="India is a Incredible country"

y=x.replace("i","*")
print(y)
# Out:
# Ind*a *s a Incred*ble country

# %%
# 7. replece i with this "*" and rest of it print in capital'''
x="India is a Incredible country"

y=x.replace("i","*")
print(y.upper())
# Out:
# IND*A *S A INCRED*BLE COUNTRY

# %%
# 8. WAP by take user input , convert first and Last alphabet in capital letter and rest in small letter''

k = input("Enter any name :- ")
a1=k[0].upper()
a2=k[-1].upper()
a3=k[1:-2].lower()
print(a1+a3+a2)
# Out:
# Enter any name :-  technical
# TechnicL

# %%
# 9. delete extraspace in x
x="     python    "
print(x.strip())
# Out:
# python

# %%
#  10. convert Text from upper to lower and lower to upper   'x="Data ScIeNce"

x="Data ScIeNce"
print(x.swapcase())
# Out:
# dATA sCiEnCE

# %%
# 11. Print all numbers from x .     x="raj135kum3444ar"

x="raj135kum3444ar"
for i in x:
    if i.isnumeric():
        print(i,end="")
# Out:
# 1353444

# %%
# 12. Write a python program to print all alphabet excluding "a"  - x="Ramayana"
x="Ramayana"
for i in x:
    if i=="a":
        continue
    print(i,end="")
# Out:
# Rmyn

# %%
# 13. print all the alphabet from x="rak1i6n5e34sh84"

# %%
# 14. print all the numeric from x="rak1i6n5e34sh84"

# %%
# 15. print all the alphabet from x="rak1i6n5e34sh84"

# %%
# 16. print all the alphabet and numeric  from x="pr1i3n5@*%$c34e44"

# %%
# 17. saperate  alphabet or numeric and store in new varaiables y and z from x
# x="pr1i3n5@*%$c34e44"

# %%
# 18. Extract special charactor from # x="pr1i3n5@*%$c34e44"

# %%
# 19. Print all elements which is written in capital letter
# x="asDFgH5jdhWEEREK345REiS"

# %%
# 20. extratct all special charactor'''
# x="Agfp445##le#@e  2$@34"

# %%
# 21. Print all elements which is written in small letter'''
# x="ghgd%^^&57GGJJKS"

# %%
# 22. count all the text from the string
# x="App 234 le#@e  234"

# %%
# 23. count and extract text and num both from the string'''
#x="App657234LPule#@e 67234"

# %%
# 24. WAP a program to sum all numerical data'''
# x="python12345"

# %%
# 25. Write a program to count the number of vowels _ string will given by user .

# %%
# 26.  find if input is special charactor then print "special" else "OKK"

# %%
# 26. x="himachal Pradesh"   extract by indexing or slicing.
#mach
#desh
#Hima
#imac
#rade

# %%
# 27. x="Arunachal"
#runa 
#Arun

# %%
# 28. WAP by take user input , convert first and Last alphabet in capital letter and rest in small letter'''

# %%
# 29. '''find value with index number 
#  x=("sun","mon","Tue","wed","Thu","fri","sat")

# %%
# 30 find value with reverse index number.
#  x=("sun","mon","Tue","wed","Thu","fri","sat")
