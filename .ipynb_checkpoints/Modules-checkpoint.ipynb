# %% [markdown]
# ## What are modules?
# Consider a  module to be the same as a code library.
# Module nothing but pyhon File.
# A file containing a set of functions you want to include in your application.
#
# Examples of python modules
# - Math
# - Random
# - Os
# - Time

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\ProgramData\anaconda3\Lib\site-packages\conda_pack\core.py:16: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ### Math Module

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.ceil(4.6)
# Out:
# 5

# %%
math.floor(4.6)
# Out:
# 4

# %%
math.factorial(5)
# Out:
# 120

# %% [markdown]
# ## Random

# %%
import random

# %%
random.randint(1,25)
# Out:
# 25

# %%
a=[3,4,5,6,7,8,9]
random.shuffle(a)
a
# Out:
# [8, 6, 4, 3, 7, 5, 9]

# %% [markdown]
# ## Time

# %%
import time

# %%
time.time() #returns the current time in seconds since January 1, 1970 (Unix epoch).
# Out:
# 1773466169.4446774

# %%
time.ctime()
# Out:
# 'Sat Mar 14 11:00:47 2026'

# %%
print("Hii")
time.sleep(2)
print("Welcome to Python")
# Out:
# Hii
# Welcome to Python

# %% [markdown]
# ## OS

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Shahid ali'

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.astropy',
#  '.conda',
#  '.continuum',
#  '.git',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.spyder-py3',
#  '.virtual_documents',
#  '.vscode',
#  'AppData',
#  'Application Data',
#  'assignment_question.ipynb',
#  'Built_in_function.ipynb',
#  'Contacts',
#  'Cookies',
#  'CrossDevice',
#  'customer_behaviour.ipynb',
#  'customer_behaviour_structured.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'jupitor_pytthon',
#  'Links',
#  'Local Settings',
#  'Microsoft',
#  'Movies',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{f492ec77-d785-11ef-8b4a-c858b3aff752}.TM.blf',
#  'NTUSER.DAT{f492ec77-d785-11ef-8b4a-c858b3aff752}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{f492ec77-d785-11ef-8b4a-c858b3aff752}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PANDAAA',
#  'Pands.ipynb',
#  'PrintHood',
#  'python_classes',
#  'Recent',
#  'recoding33.ipynb',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'source',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Videos']
